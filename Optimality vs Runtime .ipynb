# %%
import sys
import os
sys.path.insert(0, os.path.abspath('C:\\Users\\Joey\\PycharmProjects\\Automata-Testing'))
import copy
# import pydot
import optimization_functions
import graph_manager
import graph_test_methods
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz 2.44.1/bin'

# %%
data = open("C:\\Users\\Joey\\PycharmProjects\\Automata-Testing\\data\\results.txt", "w")
average_data = open("C:\\Users\\Joey\\PycharmProjects\\Automata-Testing\\data\\averaged_results.txt", "w")

ROLLOUT_INDEX = 3
NUM_SYSTEMS = 10

runtime_per_rollout_per_system = list() # runtime_per_rollout_per_system[1][2] = gives you the runtime of the 1st system, with rollout index 2
cost_per_rollout_per_system = list() # cost_per_rollout_per_system[1][2] = gives you the total cost of the 1st system, with rollout index 2
num_round_per_system_per_rollout = list()

data.write("system_index,heuristic_index,num_towers,minimized_cost_level_1_sum,minimized_cost_level_0_sum,synthesis_time,num_rounds\n")

for system_index in range(NUM_SYSTEMS):
    system = optimization_functions.get_randomized_system()
    cost_per_rollout_per_system.append([])
    runtime_per_rollout_per_system.append([])
    num_round_per_system_per_rollout.append([])
    for rollout_index in range(ROLLOUT_INDEX):        
        runtime, num_round, minimized_cost_vec = graph_manager.run_minimizing_mvp(copy.deepcopy(system), rollout_index)
        runtime_per_rollout_per_system[system_index].append(runtime)
        cost_vec_sum = None
        for cost_vec in minimized_cost_vec:
            if cost_vec_sum is None:
                cost_vec_sum = cost_vec
                continue
            for index in range(len(cost_vec)):
                cost_vec_sum[index] += cost_vec[index]
                
        cost_per_rollout_per_system[system_index].append(cost_vec_sum)
        num_round_per_system_per_rollout[system_index].append(num_round)
#         num_round_per_system.append(num_round)
        graph_manager.reset_globals()
        
#         data.write(
#             "%d,%d,%d,%d,%d,%d,%d",
#             system_index,
#             rollout_index,
#             len(system),
#             minimized_cost_vec[0],
#             minimized_cost_vec[1],
#             runtime,
#             num_round
#         )        
        
        data.write(
            str(system_index) + "," + 
            str(rollout_index) + "," + 
            str(len(system)) + "," + 
            str(cost_vec_sum[0]) + "," + 
            str(cost_vec_sum[1]) + "," + 
            str(runtime) + "," + 
            str(num_round) +
            "\n"
        )

        
        print("total runtime = " + str(runtime) + " for system with rollout index "+ str(rollout_index) + "\n\n---NEW INDEX---\n\n")
    print("\n___________________________________________________________\n")
# Out:
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [1, 1, 3, 3, 3] and ports of {'0': 3, '1': 2, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 3, 3, 3] and ports of {'0': 2, '1': 3, '2': 1}
# Tower has requests :: ['0'] and times of [2] and ports of {'0': 1}
# Tower has requests :: ['0', '1', '2'] and times of [1, 3, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 1, '1': 3}
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 3
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[2, 0, 2], [0, 2, 2], [0, 0, 2], [0, 0, 2]]
#
#  new round - completed in time 11.858124100000001
# 	round 0 breakdown ::
# 	 tower 0 took 5.9671886999999995 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 1.6461506000000004 to find most expensive request and took 3.107028100000001 to synthesize with published request
# 	 tower 2 took 0.006610399999999572 to find most expensive request and took 0.007478199999999546 to synthesize with published request
# 	 tower 3 took 0.2970783000000008 to find most expensive request and took 0.5482141000000009 to synthesize with published request
# 	 tower 4 took 0.04706649999999968 to find most expensive request and took 0.07276560000000032 to synthesize with published request
#
# Tower has requests :: ['1', '2', '0', '1'] and times of [1, 3, 3, 3] and ports of {'0': 3, '1': 2, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 3, 3, 3] and ports of {'0': 2, '1': 3, '2': 1}
# Tower has requests :: ['0'] and times of [2] and ports of {'0': 1}
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [1, 3, 2, 1] and ports of {'0': 2, '1': 2, '2': 3}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 1, '1': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [0, 2, 2], [4, 0, 2], [0, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [0, 2, 2], [2, 0, 2], [0, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [2, 0, 2], [3, 0, 2], [0, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [2, 0, 2], [0, 2, 2], [0, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [2, 0, 2], [0, 2, 2], [2, 0, 2]]
#
#  new round - completed in time 25.725752699999997
# 	round 1 breakdown ::
# 	 tower 0 took 0.6627333000000029 to find most expensive request and took 8.805363700000004 to synthesize with published request
# 	 tower 1 took 3.800000001774606e-06 to find most expensive request and took 9.070498700000002 to synthesize with published request
# 	 tower 2 took 2.59999999840943e-06 to find most expensive request and took 0.03014710000000065 to synthesize with published request
# 	 tower 3 took 0.5358235000000029 to find most expensive request and took 6.3049363999999954 to synthesize with published request
# 	 tower 4 took 3.4000000006528808e-06 to find most expensive request and took 0.3144597999999945 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 6.629922000000002 ,published request synthesis cumulative : 8.805363700000004
# tower 1 expensive request cumulative : 1.6461544000000021 ,published request synthesis cumulative : 12.177526800000003
# tower 2 expensive request cumulative : 0.006612999999997982 ,published request synthesis cumulative : 0.037625300000000195
# tower 3 expensive request cumulative : 0.8329018000000037 ,published request synthesis cumulative : 6.853150499999996
# tower 4 expensive request cumulative : 0.04706990000000033 ,published request synthesis cumulative : 0.38722539999999483
# total runtime = 37.5838768 for system with rollout index 0
#
# ---NEW INDEX---
#
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [1, 1, 3, 3, 3] and ports of {'0': 3, '1': 2, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 3, 3, 3] and ports of {'0': 2, '1': 3, '2': 1}
# Tower has requests :: ['0'] and times of [2] and ports of {'0': 1}
# Tower has requests :: ['0', '1', '2'] and times of [1, 3, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 1, '1': 3}
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 4
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [0, 2, 1], [3, 0, 1], [0, 0, 1]]
#
#  new round - completed in time 7.2634027
# 	round 0 breakdown ::
# 	 tower 0 took 4.964623799999998 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 1.2620663999999948 to find most expensive request and took 0.5664451999999969 to synthesize with published request
# 	 tower 2 took 0.004546500000003562 to find most expensive request and took 0.0026754000000011047 to synthesize with published request
# 	 tower 3 took 0.2249656999999985 to find most expensive request and took 0.08810749999999956 to synthesize with published request
# 	 tower 4 took 0.027539900000000728 to find most expensive request and took 0.015912899999996455 to synthesize with published request
#
# Tower has requests :: ['1', '2', '0', '1'] and times of [1, 3, 3, 3] and ports of {'0': 3, '1': 2, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 3, 3, 3] and ports of {'0': 2, '1': 3, '2': 1}
# Tower has requests :: ['0'] and times of [2] and ports of {'0': 1}
# Tower has requests :: ['0', '1', '2'] and times of [1, 3, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [3, 3, 1] and ports of {'0': 1, '1': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [0, 2, 1], [3, 0, 1], [0, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [0, 2, 1], [0, 0, 1], [0, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [2, 0, 1], [0, 0, 1], [0, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [2, 0, 1], [0, 2, 1], [0, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [2, 0, 1], [0, 2, 1], [0, 0, 1]]
#
#  new round - completed in time 5.3010497
# 	round 1 breakdown ::
# 	 tower 0 took 0.6617512999999988 to find most expensive request and took 1.6779486000000006 to synthesize with published request
# 	 tower 1 took 3.3000000030369847e-06 to find most expensive request and took 2.2374071000000058 to synthesize with published request
# 	 tower 2 took 2.500000000793534e-06 to find most expensive request and took 0.013174700000007533 to synthesize with published request
# 	 tower 3 took 2.500000000793534e-06 to find most expensive request and took 0.40762860000000245 to synthesize with published request
# 	 tower 4 took 0.09737140000000011 to find most expensive request and took 0.20459409999999423 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 5.626375099999997 ,published request synthesis cumulative : 1.6779486000000006
# tower 1 expensive request cumulative : 1.2620696999999979 ,published request synthesis cumulative : 2.8038523000000026
# tower 2 expensive request cumulative : 0.004549000000004355 ,published request synthesis cumulative : 0.015850100000008638
# tower 3 expensive request cumulative : 0.22496819999999929 ,published request synthesis cumulative : 0.495736100000002
# tower 4 expensive request cumulative : 0.12491130000000084 ,published request synthesis cumulative : 0.22050699999999068
# total runtime = 12.5644524 for system with rollout index 1
#
# ---NEW INDEX---
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [1, 1, 3, 3, 3] and ports of {'0': 3, '1': 2, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 3, 3, 3] and ports of {'0': 2, '1': 3, '2': 1}
# Tower has requests :: ['0'] and times of [2] and ports of {'0': 1}
# Tower has requests :: ['0', '1', '2'] and times of [1, 3, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 1, '1': 3}
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [0, 2, 2]
# cost of accepting request list :: [[4, 0, 2], [0, 2, 2], [3, 0, 2], [2, 0, 2]]
#
#  new round - completed in time 6.455750700000003
# 	round 0 breakdown ::
# 	 tower 0 took 4.668961799999998 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 1.2258718000000002 to find most expensive request and took 0.08005930000000205 to synthesize with published request
# 	 tower 2 took 0.004573200000002942 to find most expensive request and took 0.005902200000001301 to synthesize with published request
# 	 tower 3 took 0.22325030000000368 to find most expensive request and took 0.011641799999999591 to synthesize with published request
# 	 tower 4 took 0.02756790000000109 to find most expensive request and took 0.0026890999999977794 to synthesize with published request
#
# Tower has requests :: ['1', '2', '0', '1'] and times of [1, 3, 3, 3] and ports of {'0': 3, '1': 2, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 3, 3, 3] and ports of {'0': 2, '1': 3, '2': 1}
# Tower has requests :: ['0', 'no_pref'] and times of [2, 1] and ports of {'0': 1}
# Tower has requests :: ['0', '1', '2'] and times of [1, 3, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 1, '1': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [0, 2, 1]
# cost of accepting request list :: [[2, 0, 2], [1, 0, 2], [1, 0, 2], [1, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 2, 2], [2, 0, 2], [1, 0, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 0, 2], [1, 2, 2], [1, 0, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 0, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]]
#
#  new round - completed in time 5.581375399999999
# 	round 1 breakdown ::
# 	 tower 0 took 0.6604016000000001 to find most expensive request and took 1.3195630999999963 to synthesize with published request
# 	 tower 1 took 3.500000005374204e-06 to find most expensive request and took 2.806545699999994 to synthesize with published request
# 	 tower 2 took 0.002888800000000913 to find most expensive request and took 0.0239770999999962 to synthesize with published request
# 	 tower 3 took 2.4000000067303517e-06 to find most expensive request and took 0.7062259999999938 to synthesize with published request
# 	 tower 4 took 2.2999999984563146e-06 to find most expensive request and took 0.06047080000001159 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 5.329363399999998 ,published request synthesis cumulative : 1.3195630999999963
# tower 1 expensive request cumulative : 1.2258753000000056 ,published request synthesis cumulative : 2.886604999999996
# tower 2 expensive request cumulative : 0.0074620000000038544 ,published request synthesis cumulative : 0.0298792999999975
# tower 3 expensive request cumulative : 0.2232527000000104 ,published request synthesis cumulative : 0.7178677999999934
# tower 4 expensive request cumulative : 0.027570199999999545 ,published request synthesis cumulative : 0.06315990000000937
# total runtime = 12.037126100000002 for system with rollout index 2
#
# ---NEW INDEX---
#
#
#
# ___________________________________________________________
#
# Tower has requests :: ['0', '1', '2'] and times of [1, 1, 3] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0'] and times of [1] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 0
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[0, 0, 2], [3, 2, 2], [0, 0, 2], [3, 0, 2]]
#
#  new round - completed in time 7.397129800000002
# 	round 0 breakdown ::
# 	 tower 0 took 0.1971680000000049 to find most expensive request and took 0.47995179999999493 to synthesize with published request
# 	 tower 1 took 1.0170996999999886 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 2 took 1.0756517000000088 to find most expensive request and took 1.9968023999999929 to synthesize with published request
# 	 tower 3 took 0.004077000000009434 to find most expensive request and took 0.006086699999997336 to synthesize with published request
# 	 tower 4 took 0.9803476000000018 to find most expensive request and took 1.5695602000000122 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [1, 1, 3, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0'] and times of [2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0'] and times of [1] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 3
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[3, 0, 2], [2, 0, 2], [0, 0, 2], [3, 0, 2]]
#
#  new round - completed in time 3.541763099999997
# 	round 1 breakdown ::
# 	 tower 0 took 0.3765432000000004 to find most expensive request and took 1.0871661000000046 to synthesize with published request
# 	 tower 1 took 0.07608129999999846 to find most expensive request and took 0.5102784000000042 to synthesize with published request
# 	 tower 2 took 3.3000000030369847e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 3 took 2.8000000042993634e-06 to find most expensive request and took 0.006092100000003597 to synthesize with published request
# 	 tower 4 took 2.3999999996249244e-06 to find most expensive request and took 1.4714612000000074 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [1, 1, 3, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0'] and times of [2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0', 'no_pref'] and times of [1, 2] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [0, 2, 2], [0, 2, 2], [3, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 2], [0, 2, 2], [0, 2, 2], [3, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [0, 0, 2], [0, 2, 2], [2, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[4, 0, 2], [2, 0, 2], [0, 2, 2], [3, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [0, 0, 2], [0, 2, 2], [0, 2, 2]]
#
#  new round - completed in time 16.8344848
# 	round 2 breakdown ::
# 	 tower 0 took 3.3000000030369847e-06 to find most expensive request and took 5.4969538 to synthesize with published request
# 	 tower 1 took 1.9999999949504854e-06 to find most expensive request and took 2.3390090000000043 to synthesize with published request
# 	 tower 2 took 0.09817830000000072 to find most expensive request and took 2.433278299999998 to synthesize with published request
# 	 tower 3 took 0.0034873000000033016 to find most expensive request and took 0.04492759999999407 to synthesize with published request
# 	 tower 4 took 3.000000006636583e-06 to find most expensive request and took 6.417191099999997 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 0.5737145000000083 ,published request synthesis cumulative : 7.0640716999999995
# tower 1 expensive request cumulative : 1.093182999999982 ,published request synthesis cumulative : 2.8492874000000086
# tower 2 expensive request cumulative : 1.1738333000000125 ,published request synthesis cumulative : 4.430080699999991
# tower 3 expensive request cumulative : 0.007567100000017035 ,published request synthesis cumulative : 0.057106399999995006
# tower 4 expensive request cumulative : 0.980353000000008 ,published request synthesis cumulative : 9.458212500000016
# total runtime = 27.773377699999998 for system with rollout index 0
#
# ---NEW INDEX---
#
#
# Tower has requests :: ['0', '1', '2'] and times of [1, 1, 3] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0'] and times of [1] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 0
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[0, 0, 1], [3, 2, 1], [0, 0, 1], [3, 0, 1]]
#
#  new round - completed in time 4.419599399999996
# 	round 0 breakdown ::
# 	 tower 0 took 0.2049213000000094 to find most expensive request and took 0.09883539999999869 to synthesize with published request
# 	 tower 1 took 0.7555554999999998 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 2 took 1.5792110999999949 to find most expensive request and took 0.3657792999999998 to synthesize with published request
# 	 tower 3 took 0.004107399999995209 to find most expensive request and took 0.003206599999998616 to synthesize with published request
# 	 tower 4 took 0.9747883000000002 to find most expensive request and took 0.3627737000000053 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [1, 1, 3, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0'] and times of [2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0'] and times of [1] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 3
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 1], [2, 0, 1], [0, 0, 1], [3, 0, 1]]
#
#  new round - completed in time 1.5646568000000087
# 	round 1 breakdown ::
# 	 tower 0 took 0.8855286999999947 to find most expensive request and took 0.22052100000000507 to synthesize with published request
# 	 tower 1 took 0.07627050000000679 to find most expensive request and took 0.07772980000000018 to synthesize with published request
# 	 tower 2 took 3.1000000006997652e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 3 took 2.700000010236181e-06 to find most expensive request and took 0.0030607000000060225 to synthesize with published request
# 	 tower 4 took 2.300000005561742e-06 to find most expensive request and took 0.2872770999999972 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [1, 1, 3, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0'] and times of [2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0', 'no_pref'] and times of [1, 2] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [0, 2, 1], [0, 2, 1], [3, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 1], [0, 2, 1], [0, 2, 1], [3, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [0, 0, 1], [0, 2, 1], [2, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[4, 0, 1], [2, 0, 1], [0, 2, 1], [3, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [0, 0, 1], [0, 2, 1], [0, 2, 1]]
#
#  new round - completed in time 3.3774133999999947
# 	round 2 breakdown ::
# 	 tower 0 took 3.3000000030369847e-06 to find most expensive request and took 1.2709958000000086 to synthesize with published request
# 	 tower 1 took 2.00000000916134e-06 to find most expensive request and took 0.33419370000000015 to synthesize with published request
# 	 tower 2 took 0.0958445999999924 to find most expensive request and took 0.46849210000000596 to synthesize with published request
# 	 tower 3 took 0.010086200000003487 to find most expensive request and took 0.018825300000017364 to synthesize with published request
# 	 tower 4 took 3.1000000006997652e-06 to find most expensive request and took 1.1774164000000127 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 1.0904533000000072 ,published request synthesis cumulative : 1.5903522000000123
# tower 1 expensive request cumulative : 0.8318280000000158 ,published request synthesis cumulative : 0.41192350000000033
# tower 2 expensive request cumulative : 1.675058799999988 ,published request synthesis cumulative : 0.8342714000000058
# tower 3 expensive request cumulative : 0.014196300000008932 ,published request synthesis cumulative : 0.025092600000022003
# tower 4 expensive request cumulative : 0.9747937000000064 ,published request synthesis cumulative : 1.8274672000000152
# total runtime = 9.361669599999999 for system with rollout index 1
#
# ---NEW INDEX---
#
#
# Tower has requests :: ['0', '1', '2'] and times of [1, 1, 3] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0'] and times of [1] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 0
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[0, 0, 2], [3, 0, 2], [0, 0, 2], [3, 0, 2]]
#
#  new round - completed in time 3.602950000000007
# 	round 0 breakdown ::
# 	 tower 0 took 0.4601893999999902 to find most expensive request and took 0.01723029999999426 to synthesize with published request
# 	 tower 1 took 0.7561056000000121 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 2 took 1.0751895000000076 to find most expensive request and took 0.08919290000000046 to synthesize with published request
# 	 tower 3 took 0.004712699999998904 to find most expensive request and took 0.005919500000004518 to synthesize with published request
# 	 tower 4 took 0.9809213999999997 to find most expensive request and took 0.07098270000000184 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [1, 1, 3, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0'] and times of [2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0'] and times of [1] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 3
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[3, 0, 2], [2, 0, 2], [0, 0, 2], [1, 0, 2]]
#
#  new round - completed in time 1.2122256000000107
# 	round 1 breakdown ::
# 	 tower 0 took 0.8774453000000051 to find most expensive request and took 0.04293239999999798 to synthesize with published request
# 	 tower 1 took 0.07685669999999334 to find most expensive request and took 0.012727999999995632 to synthesize with published request
# 	 tower 2 took 2.7999999900885086e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 3 took 2.2000000114985596e-06 to find most expensive request and took 0.0004023999999986927 to synthesize with published request
# 	 tower 4 took 2.3999999996249244e-06 to find most expensive request and took 0.18450049999999862 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [1, 1, 3, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0'] and times of [2, 2, 1] and ports of {'0': 2, '1': 3, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [3, 2, 1] and ports of {'0': 1, '1': 1, '2': 1}
# Tower has requests :: ['0', 'no_pref'] and times of [1, 2] and ports of {'0': 2}
# Tower has requests :: ['0', '1', '2', '0'] and times of [3, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 3}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [3, 2, 2], [2, 2, 2], [2, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 0, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 2, 2], [1, 0, 2], [1, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 2, 2], [1, 0, 2], [1, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 2, 2], [1, 0, 2], [1, 2, 2], [1, 2, 2]]
#
#  new round - completed in time 6.718412700000002
# 	round 2 breakdown ::
# 	 tower 0 took 3.399999997100167e-06 to find most expensive request and took 1.227706700000013 to synthesize with published request
# 	 tower 1 took 2.199999997287705e-06 to find most expensive request and took 0.5727106000000077 to synthesize with published request
# 	 tower 2 took 0.09478469999999106 to find most expensive request and took 0.3742056999999761 to synthesize with published request
# 	 tower 3 took 0.0033728000000081693 to find most expensive request and took 0.020839300000005778 to synthesize with published request
# 	 tower 4 took 2.7999999900885086e-06 to find most expensive request and took 4.423378199999988 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 1.3376380999999924 ,published request synthesis cumulative : 1.2878694000000053
# tower 1 expensive request cumulative : 0.8329645000000028 ,published request synthesis cumulative : 0.5854386000000034
# tower 2 expensive request cumulative : 1.1699769999999887 ,published request synthesis cumulative : 0.46339859999997657
# tower 3 expensive request cumulative : 0.008087700000018572 ,published request synthesis cumulative : 0.02716120000000899
# tower 4 expensive request cumulative : 0.9809265999999894 ,published request synthesis cumulative : 4.678861399999988
# total runtime = 11.53358830000002 for system with rollout index 2
#
# ---NEW INDEX---
#
#
#
# ___________________________________________________________
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [2, 2, 2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [1, 2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 1, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [3, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 0
# lowest_new_cost [1, 1, 2]
# cost of accepting request list :: [[1, 1, 2], [2, 2, 2], [2, 0, 2], [2, 0, 2]]
#
#  new round - completed in time 14.73015500000001
# 	round 0 breakdown ::
# 	 tower 0 took 3.0273829000000063 to find most expensive request and took 3.487268599999993 to synthesize with published request
# 	 tower 1 took 0.8028967999999992 to find most expensive request and took 1.4102828999999986 to synthesize with published request
# 	 tower 2 took 0.7733408999999938 to find most expensive request and took 1.0760018000000002 to synthesize with published request
# 	 tower 3 took 3.571190299999998 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 4 took 0.0171385000000015 to find most expensive request and took 0.031326699999993934 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', '0', '1', 'no_pref'] and times of [2, 2, 2, 1, 2, 1] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 2, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 4
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[1, 1, 2], [1, 0, 2], [3, 0, 2], [0, 0, 2]]
#
#  new round - completed in time 16.851984700000003
# 	round 1 breakdown ::
# 	 tower 0 took 5.979008399999998 to find most expensive request and took 7.633403399999992 to synthesize with published request
# 	 tower 1 took 3.3000000030369847e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 2 took 3.800000001774606e-06 to find most expensive request and took 1.1094495000000109 to synthesize with published request
# 	 tower 3 took 0.49474010000000135 to find most expensive request and took 1.583635600000008 to synthesize with published request
# 	 tower 4 took 3.0000000208474376e-06 to find most expensive request and took 0.04098069999997733 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', '0', '1', 'no_pref'] and times of [2, 2, 2, 1, 2, 1] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 1, 2] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 0
# lowest_new_cost [1, 1, 2]
# cost of accepting request list :: [[1, 1, 2], [2, 0, 2], [3, 0, 2], [2, 0, 2]]
#
#  new round - completed in time 10.809935999999993
# 	round 2 breakdown ::
# 	 tower 0 took 3.7000000077114237e-06 to find most expensive request and took 7.980930000000001 to synthesize with published request
# 	 tower 1 took 0.07933570000000145 to find most expensive request and took 0.4209529000000032 to synthesize with published request
# 	 tower 2 took 3.199999980552093e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 3 took 2.6999999818144715e-06 to find most expensive request and took 1.5926948000000039 to synthesize with published request
# 	 tower 4 took 0.029183700000004364 to find most expensive request and took 0.08757560000000808 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', '0', '1', 'no_pref', 'no_pref'] and times of [2, 2, 2, 1, 2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 1, 2] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [1, 2, 1]
# cost of accepting request list :: [[2, 0, 2], [2, 0, 2], [3, 0, 2], [2, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 2, 2], [3, 0, 2], [3, 0, 2], [3, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 2, 2], [3, 0, 2], [3, 0, 2], [3, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 2, 2], [2, 0, 2], [2, 0, 2], [2, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 2, 2], [3, 0, 2], [3, 0, 2], [3, 0, 2]]
#
#  new round - completed in time 83.09340460000001
# 	round 3 breakdown ::
# 	 tower 0 took 17.643665099999993 to find most expensive request and took 54.83117439999998 to synthesize with published request
# 	 tower 1 took 3.8999999958377884e-06 to find most expensive request and took 1.6487662999999486 to synthesize with published request
# 	 tower 2 took 0.0683381000000054 to find most expensive request and took 1.4360124000000098 to synthesize with published request
# 	 tower 3 took 3.4999999911633495e-06 to find most expensive request and took 7.101210299999991 to synthesize with published request
# 	 tower 4 took 2.599999987751289e-06 to find most expensive request and took 0.36297019999997815 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 26.650060100000005 ,published request synthesis cumulative : 73.93277639999997
# tower 1 expensive request cumulative : 0.8822396999999995 ,published request synthesis cumulative : 3.4800020999999504
# tower 2 expensive request cumulative : 0.8416859999999815 ,published request synthesis cumulative : 3.621463700000021
# tower 3 expensive request cumulative : 4.065936599999972 ,published request synthesis cumulative : 10.277540700000003
# tower 4 expensive request cumulative : 0.04632780000001446 ,published request synthesis cumulative : 0.5228531999999575
# total runtime = 125.48548030000002 for system with rollout index 0
#
# ---NEW INDEX---
#
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [2, 2, 2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [1, 2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 1, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [3, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [2, 0, 1]
# cost of accepting request list :: [[2, 1, 1], [2, 2, 1], [2, 0, 1], [2, 0, 1]]
#
#  new round - completed in time 12.553316899999999
# 	round 0 breakdown ::
# 	 tower 0 took 2.8677682000000004 to find most expensive request and took 1.2339675999999997 to synthesize with published request
# 	 tower 1 took 0.7378716000000054 to find most expensive request and took 0.32880969999999365 to synthesize with published request
# 	 tower 2 took 0.7079187999999874 to find most expensive request and took 0.21641149999999243 to synthesize with published request
# 	 tower 3 took 6.285961399999991 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 4 took 0.019168000000007623 to find most expensive request and took 0.007090199999993274 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [2, 2, 2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0', 'no_pref'] and times of [2, 1, 2, 1, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 1, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 4
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 1, 1], [1, 0, 1], [3, 0, 1], [0, 0, 1]]
#
#  new round - completed in time 5.364708800000017
# 	round 1 breakdown ::
# 	 tower 0 took 3.6999999792897142e-06 to find most expensive request and took 1.0730490999999915 to synthesize with published request
# 	 tower 1 took 2.4999999936881068e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 2 took 2.5101210000000265 to find most expensive request and took 0.6831973999999832 to synthesize with published request
# 	 tower 3 took 0.7044142999999963 to find most expensive request and took 0.3738860999999929 to synthesize with published request
# 	 tower 4 took 2.999999992425728e-06 to find most expensive request and took 0.009180000000014843 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [2, 2, 2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0', 'no_pref'] and times of [2, 1, 2, 1, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 1, 2] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 1, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [2, 0, 1]
# cost of accepting request list :: [[2, 1, 1], [3, 0, 1], [4, 0, 1], [3, 0, 1]]
# accepting tower index 2
# lowest_new_cost [1, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [1, 0, 1], [3, 0, 1], [2, 0, 1]]
#
#  new round - completed in time 3.6793241999999964
# 	round 2 breakdown ::
# 	 tower 0 took 8.999999977277184e-06 to find most expensive request and took 1.3244649000000095 to synthesize with published request
# 	 tower 1 took 0.07409990000002153 to find most expensive request and took 0.15284839999998212 to synthesize with published request
# 	 tower 2 took 3.099999958067201e-06 to find most expensive request and took 0.6908907000000113 to synthesize with published request
# 	 tower 3 took 2.999999992425728e-06 to find most expensive request and took 0.756557799999996 to synthesize with published request
# 	 tower 4 took 0.06961549999999761 to find most expensive request and took 0.0391388999999549 to synthesize with published request
#
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0', 'no_pref', 'no_pref'] and times of [2, 1, 2, 1, 1, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 1, 2] and ports of {'0': 2, '1': 2}
# Optimal cost: [2, 1, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [1, 2, 1]
# cost of accepting request list :: [[2, 0, 1], [1, 2, 1], [3, 0, 1], [2, 0, 1]]
#
#  new round - completed in time 9.695835899999963
# 	round 3 breakdown ::
# 	 tower 0 took 0.43397010000001046 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 3.10000001491062e-06 to find most expensive request and took 0.08052679999997281 to synthesize with published request
# 	 tower 2 took 6.8890124999999784 to find most expensive request and took 1.4719524000000206 to synthesize with published request
# 	 tower 3 took 3.10000001491062e-06 to find most expensive request and took 0.375314899999978 to synthesize with published request
# 	 tower 4 took 2.7000000386578904e-06 to find most expensive request and took 0.019363300000009076 to synthesize with published request
#
# Tower has requests :: ['2', '0', '1'] and times of [2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0', 'no_pref', 'no_pref', 'no_pref'] and times of [2, 1, 2, 1, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 1, 2] and ports of {'0': 2, '1': 2}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 0
# lowest_new_cost [2, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [3, 0, 1], [4, 0, 1], [3, 0, 1]]
#
#  new round - completed in time 14.122852500000022
# 	round 4 breakdown ::
# 	 tower 0 took 0.08323269999999638 to find most expensive request and took 0.08761490000000549 to synthesize with published request
# 	 tower 1 took 2.6000000161729986e-06 to find most expensive request and took 0.07419650000002775 to synthesize with published request
# 	 tower 2 took 13.289149000000009 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 3 took 4.2000000348707545e-06 to find most expensive request and took 0.3845638999999892 to synthesize with published request
# 	 tower 4 took 2.6000000161729986e-06 to find most expensive request and took 0.019783200000006218 to synthesize with published request
#
# Tower has requests :: ['2', '0', '1', 'no_pref'] and times of [2, 1, 2, 1] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '2', '0', 'no_pref', 'no_pref', 'no_pref'] and times of [2, 2, 1, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 1, 2] and ports of {'0': 2, '1': 2}
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [1, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [1, 2, 1]
# cost of accepting request list :: [[2, 0, 1], [1, 2, 1], [3, 0, 1], [2, 0, 1]]
#
#  new round - completed in time 4.868430899999964
# 	round 5 breakdown ::
# 	 tower 0 took 0.7016605000000027 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 3.4000000255218765e-06 to find most expensive request and took 0.07982449999997243 to synthesize with published request
# 	 tower 2 took 2.716678999999999 to find most expensive request and took 0.6926871000000006 to synthesize with published request
# 	 tower 3 took 3.199999980552093e-06 to find most expensive request and took 0.37337700000000495 to synthesize with published request
# 	 tower 4 took 3.10000001491062e-06 to find most expensive request and took 0.019477999999992335 to synthesize with published request
#
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 2, 1] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '2', '0', 'no_pref', 'no_pref', 'no_pref', 'no_pref'] and times of [2, 2, 1, 1, 2, 2, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [1, 1, 2] and ports of {'0': 2, '1': 2}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [1, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [1, 2, 1]
# cost of accepting request list :: [[2, 0, 1], [2, 0, 1], [3, 0, 1], [2, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 1], [2, 2, 1], [4, 0, 1], [3, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 1], [2, 2, 1], [4, 0, 1], [3, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 1], [2, 0, 1], [1, 2, 1], [2, 0, 1]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 1], [3, 0, 1], [2, 2, 1], [4, 0, 1]]
#
#  new round - completed in time 14.011965700000019
# 	round 6 breakdown ::
# 	 tower 0 took 0.04448980000000802 to find most expensive request and took 0.20583979999997837 to synthesize with published request
# 	 tower 1 took 2.6999999818144715e-06 to find most expensive request and took 0.30457400000000234 to synthesize with published request
# 	 tower 2 took 6.4356008000000315 to find most expensive request and took 5.421605900000031 to synthesize with published request
# 	 tower 3 took 3.3000000030369847e-06 to find most expensive request and took 1.5198095999999737 to synthesize with published request
# 	 tower 4 took 2.5999999593295797e-06 to find most expensive request and took 0.07861150000002226 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 4.1311339999999745 ,published request synthesis cumulative : 3.9249362999999846
# tower 1 expensive request cumulative : 0.811985800000059 ,published request synthesis cumulative : 1.0207798999999511
# tower 2 expensive request cumulative : 32.54848419999999 ,published request synthesis cumulative : 9.17674500000004
# tower 3 expensive request cumulative : 6.990392500000013 ,published request synthesis cumulative : 3.7835092999999347
# tower 4 expensive request cumulative : 0.08879750000002673 ,published request synthesis cumulative : 0.1926450999999929
# total runtime = 64.29643489999998 for system with rollout index 1
#
# ---NEW INDEX---
#
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [2, 2, 2, 1, 2] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [1, 2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 1, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [3, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 0
# lowest_new_cost [2, 0, 2]
# cost of accepting request list :: [[2, 0, 2], [2, 2, 2], [2, 0, 2], [2, 0, 2]]
#
#  new round - completed in time 10.05977999999999
# 	round 0 breakdown ::
# 	 tower 0 took 2.8738182000000165 to find most expensive request and took 1.9368751000000088 to synthesize with published request
# 	 tower 1 took 0.7288533999999913 to find most expensive request and took 0.07286319999997204 to synthesize with published request
# 	 tower 2 took 0.6953237000000172 to find most expensive request and took 0.060394400000006954 to synthesize with published request
# 	 tower 3 took 3.3307035999999925 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 4 took 0.01697660000002088 to find most expensive request and took 0.0027823999999441185 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', '0', '1', 'no_pref'] and times of [2, 2, 2, 1, 2, 1] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0'] and times of [2, 1, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 2, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [1, 0, 2]
# cost of accepting request list :: [[1, 1, 2], [1, 0, 2], [3, 0, 2], [1, 0, 2]]
#
#  new round - completed in time 11.594169899999997
# 	round 1 breakdown ::
# 	 tower 0 took 9.512239800000032 to find most expensive request and took 0.9581832000000077 to synthesize with published request
# 	 tower 1 took 2.999999992425728e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 2 took 2.300000005561742e-06 to find most expensive request and took 0.1701625999999692 to synthesize with published request
# 	 tower 3 took 0.7696584000000257 to find most expensive request and took 0.08044519999998556 to synthesize with published request
# 	 tower 4 took 3.199999980552093e-06 to find most expensive request and took 0.004660600000022441 to synthesize with published request
#
# Tower has requests :: ['0', '1', '2', '0', '1', 'no_pref'] and times of [2, 2, 2, 1, 2, 1] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0', 'no_pref'] and times of [2, 1, 2, 1, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 2, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [1, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [1, 0, 2]
# cost of accepting request list :: [[2, 0, 2], [1, 0, 2], [1, 0, 2], [1, 2, 2]]
#
#  new round - completed in time 3.6057691999999975
# 	round 2 breakdown ::
# 	 tower 0 took 3.6000000136482413e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 0.07232049999998935 to find most expensive request and took 0.013603900000020985 to synthesize with published request
# 	 tower 2 took 2.8001811999999973 to find most expensive request and took 0.17442330000000084 to synthesize with published request
# 	 tower 3 took 2.5999999593295797e-06 to find most expensive request and took 0.21427619999997205 to synthesize with published request
# 	 tower 4 took 2.999999992425728e-06 to find most expensive request and took 0.008311499999990701 to synthesize with published request
#
# Tower has requests :: ['1', '2', '0', '1', 'no_pref'] and times of [2, 2, 1, 2, 1] and ports of {'0': 1, '1': 1, '2': 3}
# Tower has requests :: ['1', '2', '0'] and times of [1, 2, 1] and ports of {'0': 2, '1': 1, '2': 1}
# Tower has requests :: ['0', '1', '2', '0', 'no_pref', 'no_pref'] and times of [2, 1, 2, 1, 2, 2] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 3, 2] and ports of {'0': 3, '1': 2, '2': 1}
# Tower has requests :: ['0', '1'] and times of [1, 1] and ports of {'0': 2, '1': 2}
# Optimal cost: [1, 1, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [1, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [1, 1, 1]
# cost of accepting request list :: [[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [1, 0, 1]
# cost of accepting request list :: [[1, 1, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 2, 2], [2, 2, 2], [2, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[1, 2, 2], [2, 2, 2], [1, 2, 2], [1, 2, 2]]
#
#  new round - completed in time 21.958805700000028
# 	round 3 breakdown ::
# 	 tower 0 took 1.857472600000051 to find most expensive request and took 4.578603699999974 to synthesize with published request
# 	 tower 1 took 2.8000000042993634e-06 to find most expensive request and took 0.6485916000000316 to synthesize with published request
# 	 tower 2 took 5.49669369999998 to find most expensive request and took 4.501575699999989 to synthesize with published request
# 	 tower 3 took 3.4000000255218765e-06 to find most expensive request and took 4.763572699999997 to synthesize with published request
# 	 tower 4 took 2.7999999474559445e-06 to find most expensive request and took 0.11097269999993387 to synthesize with published request
#
# violation minimized
# round breakdown average
# tower 0 expensive request cumulative : 14.243534200000113 ,published request synthesis cumulative : 7.47366199999999
# tower 1 expensive request cumulative : 0.8011796999999774 ,published request synthesis cumulative : 0.7350587000000246
# tower 2 expensive request cumulative : 8.9922009 ,published request synthesis cumulative : 4.906555999999966
# tower 3 expensive request cumulative : 4.100368000000003 ,published request synthesis cumulative : 5.058294099999955
# tower 4 expensive request cumulative : 0.016985599999941314 ,published request synthesis cumulative : 0.12672719999989113
# total runtime = 47.21852480000001 for system with rollout index 2
#
# ---NEW INDEX---
#
#
#
# ___________________________________________________________
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [2, 2, 1, 1, 2] and ports of {'0': 3, '1': 3, '2': 2}
# Tower has requests :: ['0', '1', '2'] and times of [2, 2, 1] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1'] and times of [2, 3] and ports of {'0': 3, '1': 1}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 2, '1': 1}
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [3, 1, 3, 2, 2] and ports of {'0': 1, '1': 3, '2': 1}
# Optimal cost: [1, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [2, 1, 1]
# accepting tower index 1
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[1, 0, 2], [0, 0, 2], [0, 0, 2], [0, 0, 2]]
#
#  new round - completed in time 13.009799299999997
# 	round 0 breakdown ::
# 	 tower 0 took 3.297776400000032 to find most expensive request and took 4.04600789999995 to synthesize with published request
# 	 tower 1 took 0.17849699999999302 to find most expensive request and took 0.5027369999999678 to synthesize with published request
# 	 tower 2 took 0.025577800000007755 to find most expensive request and took 0.07073109999998906 to synthesize with published request
# 	 tower 3 took 0.028353900000013255 to find most expensive request and took 0.07567000000000235 to synthesize with published request
# 	 tower 4 took 4.450381800000002 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
#
# Tower has requests :: ['0', '1', '2', '0', '1'] and times of [2, 2, 1, 1, 2] and ports of {'0': 3, '1': 3, '2': 2}
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [2, 2, 1, 3] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1'] and times of [2, 3] and ports of {'0': 3, '1': 1}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 2, '1': 1}
# Tower has requests :: ['1', '2', '0', '1'] and times of [1, 3, 2, 2] and ports of {'0': 1, '1': 3, '2': 1}
# Optimal cost: [1, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[3, 0, 2], [0, 0, 2], [0, 0, 2], [3, 0, 2]]
#
#  new round - completed in time 4.286464599999988
# 	round 1 breakdown ::
# 	 tower 0 took 4.599999954280065e-06 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 0.4320994000000269 to find most expensive request and took 1.2757830000000467 to synthesize with published request
# 	 tower 2 took 2.999999992425728e-06 to find most expensive request and took 0.06233780000002298 to synthesize with published request
# 	 tower 3 took 2.300000005561742e-06 to find most expensive request and took 0.299937199999988 to synthesize with published request
# 	 tower 4 took 0.5150479999999789 to find most expensive request and took 1.663807600000041 to synthesize with published request
#
# Tower has requests :: ['1', '2', '0', '1'] and times of [2, 1, 1, 2] and ports of {'0': 3, '1': 3, '2': 2}
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [2, 2, 1, 3] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', 'no_pref'] and times of [2, 3, 2] and ports of {'0': 3, '1': 1}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 2, '1': 1}
# Tower has requests :: ['1', '2', '0', '1'] and times of [1, 3, 2, 2] and ports of {'0': 1, '1': 3, '2': 1}
# Optimal cost: [2, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index 2
# lowest_new_cost [0, 0, 2]
# cost of accepting request list :: [[3, 0, 2], [0, 0, 2], [0, 0, 2], [3, 0, 2]]
#
#  new round - completed in time 3.864921900000013
# 	round 2 breakdown ::
# 	 tower 0 took 0.37473829999999 to find most expensive request and took 0 to synthesize with published request <--- publishing tower
# 	 tower 1 took 3.900000024259498e-06 to find most expensive request and took 1.5735636 to synthesize with published request
# 	 tower 2 took 0.03188449999998966 to find most expensive request and took 0.12154290000000856 to synthesize with published request
# 	 tower 3 took 3.199999980552093e-06 to find most expensive request and took 0.06994159999999283 to synthesize with published request
# 	 tower 4 took 2.6000000161729986e-06 to find most expensive request and took 1.663477499999999 to synthesize with published request
#
# Tower has requests :: ['2', '0', '1'] and times of [1, 1, 2] and ports of {'0': 3, '1': 3, '2': 2}
# Tower has requests :: ['0', '1', '2', 'no_pref'] and times of [2, 2, 1, 3] and ports of {'0': 2, '1': 2, '2': 2}
# Tower has requests :: ['0', '1', 'no_pref', 'no_pref'] and times of [2, 3, 2, 2] and ports of {'0': 3, '1': 1}
# Tower has requests :: ['0', '1'] and times of [3, 3] and ports of {'0': 2, '1': 1}
# Tower has requests :: ['1', '2', '0', '1'] and times of [1, 3, 2, 2] and ports of {'0': 1, '1': 3, '2': 1}
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# Optimal cost: [0, 0, 1]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[3, 0, 2], [3, 2, 2], [0, 0, 2], [3, 0, 2]]
# accepting tower index -1
# lowest_new_cost [0, 0, 1]
# cost of accepting request list :: [[2, 0, 2], [3, 2, 2], [0, 0, 2], [3, 0, 2]]

# %%
def format_output(header, rollout_index, baseline, new):
    if new >= baseline:
        string_to_return = header +  " for rollout index " + str(rollout_index) + " :: increase by " + str(new-baseline) + "\n"
    else:
        string_to_return = header + " for rollout index " + str(rollout_index) + " :: decrease by " + str(baseline-new) + "\n"
    return string_to_return

# %%
print("block zero")
cost_increases_per_rollout_index = [[] for i in range(ROLLOUT_INDEX)]
for i in range(len(cost_increases_per_rollout_index)):
    cost_increases_per_rollout_index[i].append(0)
    cost_increases_per_rollout_index[i].append(0)

    print("block .5")
print("block one")
runtime_totals_per_rollout_index = [0 for i in range(ROLLOUT_INDEX)]
num_round_totals_per_rollout_index = [0 for i in range(ROLLOUT_INDEX)]
#print out average runtime decrease per rollout index
#print out average cost increase per rollout index
#print out average round decrease per rollout index
data.write("\n--------Summary Section--------\n\n")
for system_index in range(NUM_SYSTEMS):
    for rollout_index in range(ROLLOUT_INDEX):
        #0 and 1 represent which level of error this cost corresponds to
#         print(cost_increases_per_rollout_index)
#         print(cost_increases_per_rollout_index[rollout_index][0])
#         print(cost_per_rollout_per_system[system_index][rollout_index][0])
#         print(cost_per_rollout_per_system)
        for i in range(len(cost_per_rollout_per_system[system_index][rollout_index])):
            cost_increases_per_rollout_index[rollout_index][0] += cost_per_rollout_per_system[system_index][rollout_index][i][0]
            cost_increases_per_rollout_index[rollout_index][1] += cost_per_rollout_per_system[system_index][rollout_index][i][1]
        runtime_totals_per_rollout_index[rollout_index] += runtime_per_rollout_per_system[system_index][rollout_index]
        num_round_totals_per_rollout_index[rollout_index] += num_round_per_system_per_rollout[system_index][rollout_index]
print("block two")

# "Average cost for rollout index" + str(rollout_index) + " :: " + "increase by " 
average_level_1_cost_per_rollout_index = []
average_level_0_cost_per_rollout_index = []
average_runtime_totals_per_rollout_index = []
average_num_rounds_per_rollout_index = []
for rollout_index in range(ROLLOUT_INDEX):
    average_level_1_cost_per_rollout_index.append(cost_increases_per_rollout_index[rollout_index][0]/NUM_SYSTEMS)
    average_level_0_cost_per_rollout_index.append(cost_increases_per_rollout_index[rollout_index][1]/NUM_SYSTEMS) 
    average_runtime_totals_per_rollout_index.append(runtime_totals_per_rollout_index[rollout_index]/NUM_SYSTEMS)
    average_num_rounds_per_rollout_index.append(num_round_totals_per_rollout_index[rollout_index]/NUM_SYSTEMS)
print("block three")

data.write("Average level 1 cost for rollout index 0 :: " + str(average_level_1_cost_per_rollout_index[0]) + "\n")
for i in range(1, ROLLOUT_INDEX):
    data.write(format_output("Average level 1 cost", i, average_level_1_cost_per_rollout_index[0], average_level_1_cost_per_rollout_index[i]))

data.write("Average level 0 cost for rollout index 0 :: " + str(average_level_1_cost_per_rollout_index[0])+ "\n")
for i in range(1, ROLLOUT_INDEX):
    data.write(format_output("Average level 0 cost", i,average_level_0_cost_per_rollout_index[0], average_level_0_cost_per_rollout_index[i]))

data.write("Average synthesis runtime for rollout index 0 :: " + str(average_runtime_totals_per_rollout_index[0])+ "\n")
for i in range(1, ROLLOUT_INDEX):
    data.write(format_output("Average synthesis runtime", i, average_runtime_totals_per_rollout_index[0], average_runtime_totals_per_rollout_index[i]))

data.write("Average num rounds for rollout index 0 :: " + str(average_runtime_totals_per_rollout_index[0])+ "\n")
for i in range(1, ROLLOUT_INDEX):
    data.write(format_output("Average num rounds", i, average_num_rounds_per_rollout_index[0], average_num_rounds_per_rollout_index[i]))
    
data.close()
average_data.close()
